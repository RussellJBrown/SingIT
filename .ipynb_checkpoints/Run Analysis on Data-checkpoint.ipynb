# %%
#This method is the main method
#For training the dataset.
import sys
import os
from pydub import AudioSegment
import librosa

# %%
import os


locationEnglish = "/media/russell/775C-44EC/English"
locationGerman = "/media/russell/775C-44EC/German"
locationJapanese = "/media/russell/775C-44EC/Japanese"
locationFrench = "/media/russell/775C-44EC/French"

dirEnglish =  os.listdir(locationEnglish)
dirGerman =   os.listdir(locationGerman)
dirJapanese = os.listdir(locationJapanese)
dirFrench   = os.listdir(locationFrench)

for i in dirEnglish:
    name, ext = os.path.splitext(i)
    print(ext)
    if(ext=='.wav'):
        name = os.path.splitext(i)[0]
        name2 = name[-3:]
        if (name2=="Out"):
                os.remove(locationEnglish+"/"+i)
                print("Delete: ")
                print(i)


for i in dirGerman:
    name, ext = os.path.splitext(i)
    print(ext)
    if(ext=='.wav'):
        name = os.path.splitext(i)[0]
        name2 = name[-3:]
        if (name2=="Out"):
                os.remove(locationGerman+"/"+i)
                print("Delete: ")
                print(i)


for i in dirJapanese:
    name, ext = os.path.splitext(i)
    print(ext)
    if(ext=='.wav'):
        name = os.path.splitext(i)[0]
        name2 = name[-3:]
        if (name2=="Out"):
                os.remove(locationJapanese+"/"+i)
                print("Delete: ")
                print(i)


for i in dirFrench:
    name, ext = os.path.splitext(i)
    print(ext)
    if(ext=='.wav'):
        name = os.path.splitext(i)[0]
        name2 = name[-3:]
        if (name2=="Out"):
                os.remove(locationFrench+"/"+i)
                print("Delete: ")
                print(i)
# Out:
# .py
# .txt
# .txt
# .py
# .wav
# Delete:
# TheBlackEyedPeas-PumpItOfficialMusicVideo-ZaI2IlHwmgQOut.wav
# .wav
# Delete:
# OneDirection-OneWayOrAnotherTeenageKicks-36mCEZzzQ3oOut.wav
# .wav
# Delete:
# Rihanna-FourFiveSecondsft.KanyeWest&PaulMcCartnery[LYRICS]-FjRPDzcmJT4Out.wav
# .wav
# Delete:
# LikeImGonnaLoseYou-MeghanTrainorft.JohnLegendLyrics-DC8FsIdVi9YOut.wav
# .wav
# Delete:
# WizKhalifa-SeeYouAgainft.CharliePuth[OfficialVideo]Furious7Soundtrack-RgKAFK5djSkOut.wav
# .wav
# Delete:
# Maroon5-MapsLyricVideo-Y7ix6RITXM0Out.wav
# .wav
# Delete:
# MeghanTrainor-MeTooOfficialMusicVideo-qDRORgoZxZUOut.wav
# .wav
# Delete:
# EdSheeran-PhotographOfficialMusicVideo-nSDgHBxUbVQOut.wav
# .wav
# Delete:
# YoungThug-TheLondonft.J.Cole&TravisScott[OfficialAudio]-OKhT_6XtD7IOut.wav
# .wav
# Delete:
# Evanescence-MyImmortalOfficialMusicVideo-5anLPw0EfmoOut.wav
# .wav
# Delete:
# CalvinHarris-ThisIsWhatYouCameForOfficialVideoft.Rihanna-kOkQ4T5WO9EOut.wav
# .wav
# Delete:
# SelenaGomez-KillEmWithKindness-HHP5MKgK0o8Out.wav
# .wav
# Delete:
# FifthHarmony-WorthItft.KidInk-YBHQbu5rbdQOut.wav
# .wav
# Delete:
# NoDoubt-DontSpeakOfficialMusicVideo-TR3Vdo5etCQOut.wav
# .wav
# Delete:
# Kiesza-HideawayOfficialMusicVideo-Vnoz5uBEWOAOut.wav
# .wav
# Delete:
# KatyPerry-UnconditionallyOfficial-XjwZAa2EjKAOut.wav
# .wav
# Delete:
# CapitalCities-SafeAndSoundOfficialMusicVideo-47dtFZ8CFo8Out.wav
# .wav
# Delete:
# FrenchMontana-Unforgettableft.SwaeLeeOfficialMusicVideo-CTFtOOh47ooOut.wav
# .wav
# Delete:
# SnoopDogg&WizKhalifa-Young,WildandFreeft.BrunoMars[OfficialVideo]-Wa5B22KAkEkOut.wav
# .wav
# Delete:
# Drake-InMyFeelings-DRS_PpOrUZ4Out.wav
# .wav
# Delete:
# BonJovi-Always-9BMwcO6_hyAOut.wav
# .wav
# Delete:
# RobinSchulz-Sugarfeat.FrancescoYatesOFFICIALMUSICVIDEO-bvC_0foemLYOut.wav
# .wav
# Delete:
# Eminem-BeautifulOfficialMusicVideo-lgT1AidzRWMOut.wav
# .wav
# Delete:
# JessieJ-FlashlightfromPitchPerfect2-DzwkcbTQ7ZEOut.wav
# .wav
# Delete:
# Migos-T-Shirt[OfficialVideo]-1VUa99-tJqsOut.wav
# .wav
# Delete:
# 50Cent-CandyShopft.OliviaOfficialVideo-SRcnnId15BAOut.wav
# .wav
# Delete:
# JustinBieber-LoveYourselfOfficialVideo-oyEuk8j8imIOut.wav
# .wav
# Delete:
# BonJovi-LivinOnAPrayer-lDK9QqIzhwkOut.wav
# .wav
# Delete:
# Sia-ChandelierOfficialMusicVideo-2vjPBrBU-TMOut.wav
# .wav
# Delete:
# a-ha-TakeOnMeOfficialMusicVideo-djV11Xbc914Out.wav
# .wav
# Delete:
# EllieGoulding-BurnLyrics-xscJ8Lla6GcOut.wav
# .wav
# Delete:
# TaylorSwift-ShakeItOff-nfWlot6h_JMOut.wav
# .wav
# Delete:
# Shakira-Whenever,WhereverVideo-weRHyjj34ZEOut.wav
# .wav
# Delete:
# SuckerForPainwithLogic,TyDolla$ign&XAmbassadors-6I2y_UbVz4UOut.wav
# .wav
# Delete:
# DJKhaled-ImTheOneft.JustinBieber,Quavo,ChancetheRapper&LilWayneOfficialVideo-weeI1G46q0oOut.wav
# .wav
# Delete:
# OneDirection-PerfectOfficialVideo-Ho32Oh6b4jcOut.wav
# .wav
# Delete:
# MajorLazer&DJSnake-LeanOnfeat.MØOfficialMusicVideo-YqeW9_5kURIOut.wav
# .wav
# Delete:
# Rihanna-UmbrellaOrangeVersionft.JAY-Z-CvBfHwUxHIkOut.wav
# .wav
# Delete:
# MarkRonson-UptownFunkOfficialVideoft.BrunoMars-OPf0YbXqDm0Out.wav
# .wav
# Delete:
# Silentó-WatchMeWhip_NaeNaeOfficialMusicVideo-vjW8wmF5VWcOut.wav
# .wav
# Delete:
# MichaelJackson-TheyDon’tCareAboutUsBrazilVersionOfficialVideo-QNJL6nfu__QOut.wav
# .wav
# Delete:
# TaylorSwift-IKnewYouWereTrouble-vNoKguSdy4YOut.wav
# .wav
# Delete:
# RedHotChiliPeppers-Californication[OfficialMusicVideo]-YlUKcNNmywkOut.wav
# .wav
# Delete:
# Nico&Vinz-AmIWrong[OfficialMusicVideo]-bg1sT4ILG0wOut.wav
# .wav
# Delete:
# EdSheeran-ThinkingOutLoud[OfficialVideo]-lp-EO5I60KAOut.wav
# .wav
# Delete:
# JasonDerulo-WantToWantMeOfficialVideo-rClUOdS5ZywOut.wav
# .wav
# Delete:
# LanaDelRey-BornToDieOfficialMusicVideo-Bag1gUxuU0gOut.wav
# .wav
# Delete:
# Avicii-WakeMeUpOfficialVideo-IcrbM1l_BoIOut.wav
# .wav
# Delete:
# Eminem-LoveTheWayYouLieft.Rihanna-uelHwf8o7_UOut.wav
# .wav
# Delete:
# MAGIC!-RudeOfficialMusicVideo-PIh2xe4jnpkOut.wav
# .wav
# Delete:
# NickyRomero-Toulouse-KrVC5dm5fFcOut.wav
# .wav
# Delete:
# MeghanTrainor-DearFutureHusbandOfficialMusicVideo-ShlW5plD_40Out.wav
# .wav
# Delete:
# TaylorSwift-BlankSpace-e-ORhEE9VVgOut.wav
# .wav
# Delete:
# CyndiLauper-GirlsJustWantToHaveFunOfficialVideo-PIb6AZdTr-AOut.wav
# .wav
# Delete:
# EraIstrefi-BonbonEnglishVersionCoverArt-vxc1ufJxPGMOut.wav
# .wav
# Delete:
# Scorpions-WindOfChangeOfficialMusicVideo-n4RjJKxsamQOut.wav
# .wav
# Delete:
# Marshmello-Alone[MonstercatOfficialMusicVideo]-YnwsMEabmSoOut.wav
# .wav
# Delete:
# DavidGuetta-TurnMeOnft.NickiMinajLyricVideo-WLTI2rWAlV4Out.wav
# .wav
# Delete:
# ArianaGrande-DangerousWoman-9WbCfHutDSEOut.wav
# .wav
# Delete:
# Ke$ha-TiKToKOfficialMusicVideo-iP6XpLQM2CsOut.wav
# .wav
# Delete:
# AGreatBigWorld&ChristinaAguilera-SaySomethingOfficialVideo--2U0Ivkn2DsOut.wav
# .wav
# Delete:
# Queen–BohemianRhapsodyOfficialVideoRemastered-fJ9rUzIMcZQOut.wav
# .wav
# Delete:
# Tyga-HookahOfficialMusicVideoft.YoungThug-b-J95fYuVz4Out.wav
# .wav
# Delete:
# Adele-Hello-YQHsXMglC9AOut.wav
# .wav
# Delete:
# B.o.B-Airplanesfeat.HayleyWilliamsofParamore[OfficialVideo]-kn6-c223DUUOut.wav
# .wav
# Delete:
# KidCudi-CudderisbackOfficialMusicVideo-qDXBpUtiX1EOut.wav
# .wav
# Delete:
# FifthHarmony-WorkfromHomeft.TyDolla$ign-5GL9JoH4SwsOut.wav
# .wav
# Delete:
# AnnaKendrick-CupsPitchPerfect’s“WhenI’mGone”[OfficialVideo]-cmSbXsFE3l8Out.wav
# .wav
# Delete:
# NENA_99RedBalloons-Q86nf7mpOXkOut.wav
# .wav
# Delete:
# Maroon5-Sugar-09R8_2nJtjgOut.wav
# .wav
# Delete:
# Adele-SendMyLoveToYourNewLover-fk4BbF7B29wOut.wav
# .wav
# Delete:
# LukasGraham-7Years[OFFICIALMUSICVIDEO]-LHCob76kigAOut.wav
# .wav
# Delete:
# Shakira-WakaWakaThisTimeforAfricaTheOfficial2010FIFAWorldCup™Song-pRpeEdMmmQ0Out.wav
# .wav
# Delete:
# Beyoncé-RuntheWorldGirlsVideo-MainVersion-VBmMU_iwe6UOut.wav
# .wav
# Delete:
# TheBlackEyedPeas-TheTimeDirtyBitAudio-D7K3wFXJFsQOut.wav
# .wav
# Delete:
# EllieGoulding-LoveMeLikeYouDoOfficialVideo-AJtDXIazrMoOut.wav
# .wav
# Delete:
# BrunoMars-TreasureOfficialVideo-nPvuNsRccVwOut.wav
# .wav
# Delete:
# NevPlays-Skrillex-FirstoftheYearEquinoxLaunchpadCover-SAXpBgkXt60Out.wav
# .wav
# Delete:
# GunsNRoses-DontCry-zRIbf6JqkNcOut.wav
# .wav
# Delete:
# SelenaGomez-GoodForYou-1TsVjvEkc4sOut.wav
# .wav
# Delete:
# DimitriVegas,MartinGarrix,LikeMike-TremorOfficialMusicVideo-9vMh9f41pqEOut.wav
# .wav
# Delete:
# LilNasX-OldTownRoadfeat.BillyRayCyrus[Remix]-7ysFgElQtjIOut.wav
# .wav
# Delete:
# LMFAOft.LaurenBennett,GoonRock-PartyRockAnthemOfficialVideo-KQ6zr6kCPj8Out.wav
# .wav
# Delete:
# Aqua-BarbieGirlOfficialVideo-ZyhrYis509AOut.wav
# .wav
# Delete:
# Passenger_LetHerGoOfficialVideo-RBumgq5yVrAOut.wav
# .wav
# Delete:
# APES_T-THECARTERS-kbMqWXnpXcAOut.wav
# .wav
# Delete:
# Rihanna-DontStopTheMusic-yd8jh9QYfEsOut.wav
# .wav
# Delete:
# JustinBieber-WhatDoYouMeanOfficialMusicVideo-DK_0jXPuIr0Out.wav
# .wav
# Delete:
# MoneyInTheGrave-JFOiJ5ZvQlEOut.wav
# .wav
# Delete:
# R.E.M.-LosingMyReligionOfficialMusicVideo-xwtdhWltSIgOut.wav
# .wav
# Delete:
# Adele-SetFireToTheRainLiveatTheRoyalAlbertHall-Ri7-vnrJD3kOut.wav
# .wav
# Delete:
# KatyPerry-RoarOfficial-CevxZvSJLk8Out.wav
# .wav
# Delete:
# Drake-HotlineBling-uxpDa-c-4McOut.wav
# .wav
# Delete:
# Drake-GodsPlan-xpVfcZ0ZcFMOut.wav
# .wav
# Delete:
# Nelly-Dilemmaft.KellyRowlandOfficialMusicVideo-8WYHDfJDPDcOut.wav
# .wav
# Delete:
# GoodFeeling-Q_mQxKviRJMOut.wav
# .wav
# Delete:
# ZaraLarsson,MNEK-NeverForgetYouOfficialMusicVideo-GTyN-DB_v5MOut.wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .py
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .txt
# .txt
# .txt
# .txt
# .py
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .txt
# .txt
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .txt
# .txt
# .wav
# .txt
# .txt
# .py
# .txt
# .txt
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# .wav
# Delete:
# M.Pokora-JusteUnePhotoDeToi-lcSakE8U6lkOut.wav
# .wav
# Delete:
# CoeurdepirateCommedesEnfantsParoles-sQnlR2effdQOut.wav
# .wav
# Delete:
# Stromae-PapaoutaiClipOfficiel-oiKj0Z_XnjcOut.wav
# .wav
# Delete:
# BBBRUNES-CoupsetBlessures[ClipOfficiel]-mF5etHMRMMMOut.wav
# .wav
# Delete:
# MaîtreGims-JmetireAudio-8Si2q_rxvWAOut.wav
# .wav
# Delete:
# GénérationGoldman-JetedonneLeslie&IvyriseCLIPOFFICIEL-wjud3Ue-pFEOut.wav
# .wav
# Delete:
# Indila-DernièreDanseClipOfficiel-K5KAc5CoCukOut.wav
# .wav
# Delete:
# Soprano-CosmoLiveauxTRACEUrbanMusicAwards2014#TRACEAWARDS-FomT_qar0GEOut.wav
# .wav
# Delete:
# SexiondAssaut-MadirectionClipofficiel-Y7-vP7TnluYOut.wav
# .wav
# Delete:
# ChristopheMaé-JeMeLâcheClipOfficiel-BvIvwHoG5fsOut.wav
# .wav
# Delete:
# Mika-ElleMeDitclipofficiel-NiHWwKC8WjUOut.wav
# .wav
# Delete:
# Stromae-AlorsOnDanseClipOfficiel-VHoT4N43jK8Out.wav
# .wav
# Delete:
# FAUVE-NuitsFauves-cwaAppsy5yoOut.wav
# .wav
# Delete:
# LaFemme-SurLaPlanche2013-NwVA5zYfNWwOut.wav
# .wav
# Delete:
# JulienDoré-Paris-SeychellesClipofficiel-cmE_aahc448Out.wav
# .wav
# Delete:
# TAL-RienNestParfaitClipOfficiel-4J39Ol6T0XwOut.wav
# .wav
# Delete:
# BlackM-SurmarouteClipofficiel-U-Z_bZS8t3MOut.wav
# .wav
# Delete:
# CalogeroUnjouraumauvaisendroit-Càvous-04_09_2014-i0p5aZBvAooOut.wav
# .wav
# Delete:
# MagicSystem-TuesfouMakingof-bPxwu5OZ-HMOut.wav
# .wav
# Delete:
# KendjiGirac-ColorGitanoOfficialVideo-63K5VMx2BZMOut.wav
# .wav
# Delete:
# Diams-DanslenoirAudioofficiel-f6GHAbenqvMOut.wav
# .wav
# Delete:
# JoyceJonathan_Çaira_BoulevarddesPlanches2013-mOuzyjsGYXcOut.wav
# .wav
# Delete:
# JenaLee-DuStyle-TL-q_xCggTEOut.wav
# .wav
# Delete:
# FAUVE≠BLIZZARD-519_pOvP9xsOut.wav
# .wav
# Delete:
# M.Pokora-Lejourquiserêve-vCRThAYKXEcOut.wav
# .wav
# Delete:
# Toma-LesbâtisseursdeFranceclipofficiel-7l2o1tgFZGkOut.wav
# .wav
# Delete:
# Khaled-CestlavieClipofficiel-H7rhMqTQ4WIOut.wav
# .wav
# Delete:
# AaRON-LeTunneldOrSymphonique-VcViDBhgJrMOut.wav
# .wav
# Delete:
# LesOgresdeBarback-Contes,VentsetMarées-hoPIDJy93NcOut.wav
# .wav
# Delete:
# SheryfaLuna-QuelquePart-uDyHQGHic0IOut.wav
# .wav
# Delete:
# Yelle-ComplètementfouOfficialVideo-13o1i-cgTOAOut.wav
# .wav
# Delete:
# Luce-MangerDuSable-O8Lv32YyAgUOut.wav
# .wav
# Delete:
# Bensé-Augrandjamais-O8MClBoNlfEOut.wav
# .wav
# Delete:
# NatashaSt-Pier-BonnenouvelleClipofficiel-egwvEm3nbmcOut.wav
# .wav
# Delete:
# CarlaBruni-Quelquunmadit-EC7Re8cczj0Out.wav
# .wav
# Delete:
# VanessaParadis-IlYALive2009-jyBN6lbhUFMOut.wav
# .wav
# Delete:
# MozartOperaRock-CestBientôtLaFinClipofficiel-aS1SGkWoHecOut.wav
# .wav
# Delete:
# Shym-EtAlors!ClipOfficiel-2zdqymnZoHcOut.wav
# .wav
# Delete:
# ZahoLiveJetePromets-hmF_AasWf2gOut.wav
# .wav
# Delete:
# YannickNoah-OseClipofficiel-AW5zbbXbaN4Out.wav
# .wav
# Delete:
# Orelsan-IlssontCools[Live]-tPXHhB8woycOut.wav
# .wav
# Delete:
# JesuisunHommewithlyrics-tB-zasOL29YOut.wav
# .wav
# Delete:
# Kyo-JecoursClipofficiel-zSpLOlxy9nIOut.wav
# .wav
# Delete:
# Coeurdepirate-Ensemble[Vidéoclipofficiel]-i3u0vq0WyIAOut.wav
# .wav
# Delete:
# OliviaRuiz-JTraineDesPieds-uduL7z8BkOsOut.wav
# .wav
# Delete:
# VanessaParadis-DivineIdylleLive2009-V82wcQbfZmcOut.wav
# .wav
# Delete:
# Tesbeau-PaulineCrozeBataclan-2008-XzoirUEntugOut.wav
# .wav
# Delete:
# NoblesseOblige-JalouseMusicVideo-pv-49f38H9MOut.wav
# .wav
# Delete:
# Maissiat-Trésor-AfkiMp7piiYOut.wav
# .wav
# Delete:
# MélaniePainIgnore-moiacoustique-2wicVDVQzzMOut.wav
# .wav
# Delete:
# Indochine-JaidemandéàlaluneClipofficiel-KAOmC5qT02wOut.wav
# .wav
# Delete:
# MelissaNKonda-NouveauxHorizonsclip-21NYo61E3M4Out.wav
# .wav
# Delete:
# MCSolar-SolaarPleure.flv-2uktfm6uGAEOut.wav
# .wav
# Delete:
# AmandineBourgeois-TantdeMoi[+Paroles]-N6dAfbR5kK4Out.wav
# .wav
# Delete:
# Diams-JeuneDemoiselleGeysterRemix-2006-LuAQHcYDuYYOut.wav
# .wav
# Delete:
# GéraldDePalmas-UneSeuleVie2000-p9_B9UABex0Out.wav
# .wav
# Delete:
# RENANLUCE-Lalettre-7Vv5sDQ9aFUOut.wav
# .wav
# Delete:
# Melissmell-12.SensMaFatigue[Ecoutesilpleut]-6XHwKRnDZmkOut.wav
# .wav
# Delete:
# JENIFER-SurlefilHitWestLive2012-lgUHb-_t2_UOut.wav
# .wav
# Delete:
# GénérationGoldmanEnvoleMoiMPokora&TalHD-PHWzFM_HxvoOut.wav
# .wav
# Delete:
# Booba-PanameParolesHD2011Lyrics-0EGrlRA9Ut8Out.wav

# %%
def betterVocalExtract(song,language):
    song = '"'+song+'"'
    command = "spleeter separate -i "+ song + " -p spleeter:2stems -o output"+language
    print("Start Command")
    os.system(command)
    print("Finished Command")

# %%
def libroExtract(inputSong):
    name = os.path.splitext(inputSong)[0]
    extension = os.path.splitext(inputSong)[1]
    outSong = name + "Out" + extension
    outSong = outSong.replace("(","")
    outSong = outSong.replace(")","")
    outSong = outSong.replace("'","")
    outSong = outSong.replace('"','')
    outSong = outSong.replace(" ",'')
    y, sr = librosa.load(inputSong,offset=35.0,duration=30)
    librosa.output.write_wav(outSong,y,sr)
    return outSong

# %%
def readInWav(local, wavFile):
        wavFile = local+wavFile
        outFile=libroExtract(wavFile)
        return outFile

# %%
locationEnglish = "/media/russell/775C-44EC/English"
dirEnglish =  os.listdir(locationEnglish)
count = 0
for i in range(0,len(dirEnglish)):
    englishSong = dirEnglish[i]
    name, ext = os.path.splitext(englishSong)
    if(ext=='.wav'):
            count +=1
            print("Song Number: ")
            print(count)
            output = readInWav(locationEnglish+"/",englishSong)
            betterVocalExtract(output,"English")
# Out:
# Song Number:
# 1
# Start Command
# Finished Command
# Song Number:
# 2
# Start Command
# Finished Command
# Song Number:
# 3
# Start Command
# Finished Command
# Song Number:
# 4
# Start Command
# Finished Command
# Song Number:
# 5
# Start Command
# Finished Command
# Song Number:
# 6
# Start Command
# Finished Command
# Song Number:
# 7
# Start Command
# Finished Command
# Song Number:
# 8
# Start Command
# Finished Command
# Song Number:
# 9
# Start Command
# Finished Command
# Song Number:
# 10
# Start Command
# Finished Command
# Song Number:
# 11
# Start Command
# Finished Command
# Song Number:
# 12
# Start Command
# Finished Command
# Song Number:
# 13
# Start Command
# Finished Command
# Song Number:
# 14
# Start Command
# Finished Command
# Song Number:
# 15
# Start Command
# Finished Command
# Song Number:
# 16
# Start Command
# Finished Command
# Song Number:
# 17
# Start Command
# Finished Command
# Song Number:
# 18
# Start Command
# Finished Command
# Song Number:
# 19
# Start Command
# Finished Command
# Song Number:
# 20
# Start Command
# Finished Command
# Song Number:
# 21
# Start Command
# Finished Command
# Song Number:
# 22
# Start Command
# Finished Command
# Song Number:
# 23
# Start Command
# Finished Command
# Song Number:
# 24
# Start Command
# Finished Command
# Song Number:
# 25
# Start Command
# Finished Command
# Song Number:
# 26
# Start Command
# Finished Command
# Song Number:
# 27
# Start Command
# Finished Command
# Song Number:
# 28
# Start Command
# Finished Command
# Song Number:
# 29
# Start Command
# Finished Command
# Song Number:
# 30
# Start Command
# Finished Command
# Song Number:
# 31
# Start Command
# Finished Command
# Song Number:
# 32
# Start Command
# Finished Command
# Song Number:
# 33
# Start Command
# Finished Command
# Song Number:
# 34
# Start Command
# Finished Command
# Song Number:
# 35
# Start Command
# Finished Command
# Song Number:
# 36
# Start Command
# Finished Command
# Song Number:
# 37
# Start Command
# Finished Command
# Song Number:
# 38
# Start Command
# Finished Command
# Song Number:
# 39
# Start Command
# Finished Command
# Song Number:
# 40
# Start Command
# Finished Command
# Song Number:
# 41
# Start Command
# Finished Command
# Song Number:
# 42
# Start Command
# Finished Command
# Song Number:
# 43
# Start Command
# Finished Command
# Song Number:
# 44
# Start Command
# Finished Command
# Song Number:
# 45
# Start Command
# Finished Command
# Song Number:
# 46
# Start Command
# Finished Command
# Song Number:
# 47
# Start Command
# Finished Command
# Song Number:
# 48
# Start Command
# Finished Command
# Song Number:
# 49
# Start Command
# Finished Command
# Song Number:
# 50
# Start Command
# Finished Command
# Song Number:
# 51
# Start Command
# Finished Command
# Song Number:
# 52
# Start Command
# Finished Command
# Song Number:
# 53
# Start Command
# Finished Command
# Song Number:
# 54
# Start Command
# Finished Command
# Song Number:
# 55
# Start Command
# Finished Command
# Song Number:
# 56
# Start Command
# Finished Command
# Song Number:
# 57
# Start Command
# Finished Command
# Song Number:
# 58
# Start Command
# Finished Command
# Song Number:
# 59
# Start Command
# Finished Command
# Song Number:
# 60
# Start Command
# Finished Command
# Song Number:
# 61
# Start Command
# Finished Command
# Song Number:
# 62
# Start Command
# Finished Command
# Song Number:
# 63
# Start Command
# Finished Command
# Song Number:
# 64
# Start Command
# Finished Command
# Song Number:
# 65
# Start Command
# Finished Command
# Song Number:
# 66
# Start Command
# Finished Command
# Song Number:
# 67
# Start Command
# Finished Command
# Song Number:
# 68
# Start Command
# Finished Command
# Song Number:
# 69
# Start Command
# Finished Command
# Song Number:
# 70
# Start Command
# Finished Command
# Song Number:
# 71
# Start Command
# Finished Command
# Song Number:
# 72
# Start Command
# Finished Command
# Song Number:
# 73
# Start Command
# Finished Command
# Song Number:
# 74
# Start Command
# Finished Command
# Song Number:
# 75
# Start Command
# Finished Command
# Song Number:
# 76
# Start Command
# Finished Command
# Song Number:
# 77
# Start Command
# Finished Command
# Song Number:
# 78
# Start Command
# Finished Command
# Song Number:
# 79
# Start Command
# Finished Command
# Song Number:
# 80
# Start Command
# Finished Command
# Song Number:
# 81
# Start Command
# Finished Command
# Song Number:
# 82
# Start Command
# Finished Command
# Song Number:
# 83
# Start Command
# Finished Command
# Song Number:
# 84
# Start Command
# Finished Command
# Song Number:
# 85
# Start Command
# Finished Command
# Song Number:
# 86
# Start Command
# Finished Command
# Song Number:
# 87
# Start Command
# Finished Command
# Song Number:
# 88
# Start Command
# Finished Command
# Song Number:
# 89
# Start Command
# Finished Command
# Song Number:
# 90
# Start Command
# Finished Command
# Song Number:
# 91
# Start Command
# Finished Command
# Song Number:
# 92
# Start Command
# Finished Command
# Song Number:
# 93
# Start Command
# Finished Command
# Song Number:
# 94
# Start Command
# Finished Command
# Song Number:
# 95
# Start Command
# Finished Command
# Song Number:
# 96
# Start Command
# Finished Command
# Song Number:
# 97
# Start Command
# Finished Command
# Song Number:
# 98
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-a15c057d067a> in <module>()
#       9             print("Song Number: ")
#      10             print(count)
# ---> 11             output = readInWav(locationEnglish+"/",englishSong)
#      12             betterVocalExtract(output,"English")
#
# <ipython-input-20-cce7b311cb29> in readInWav(local, wavFile)
#       1 def readInWav(local, wavFile):
#       2         wavFile = local+wavFile
# ----> 3         outFile=libroExtract(wavFile)
#       4         return outFile
#
# <ipython-input-19-16362b8766ea> in libroExtract(inputSong)
#       8     outSong = outSong.replace('"','')
#       9     outSong = outSong.replace(" ",'')
# ---> 10     y, sr = librosa.load(inputSong,offset=35.0,duration=30)
#      11     librosa.output.write_wav(outSong,y,sr)
#      12     return outSong
#
# ~/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     147
#     148     if sr is not None:
# --> 149         y = resample(y, sr_native, sr, res_type=res_type)
#     150
#     151     else:
#
# ~/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py in resample(y, orig_sr, target_sr, res_type, fix, scale, **kwargs)
#     517         y_hat = scipy.signal.resample_poly(y, target_sr // gcd, orig_sr // gcd, axis=-1)
#     518     else:
# --> 519         y_hat = resampy.resample(y, orig_sr, target_sr, filter=res_type, axis=-1)
#     520
#     521     if fix:
#
# ~/anaconda3/lib/python3.7/site-packages/resampy/core.py in resample(x, sr_orig, sr_new, axis, filter, **kwargs)
#     118     x_2d = x.swapaxes(0, axis).reshape((x.shape[axis], -1))
#     119     y_2d = y.swapaxes(0, axis).reshape((y.shape[axis], -1))
# --> 120     resample_f(x_2d, y_2d, sample_ratio, interp_win, interp_delta, precision)
#     121
#     122     return y
#
# KeyboardInterrupt:

# %%
locationFrench = "/media/russell/775C-44EC/French"
dirFrench = os.listdir(locationFrench)
count = 0
for l in range(0,len(dirFrench)):
        frenchSong = dirFrench[l]
        name, ext = os.path.splitext(frenchSong)
        if(ext=='.wav'):
            count += 1
            print("Song Number: ")
            print(count)
            output = readInWav(locationFrench+"/",frenchSong)
            betterVocalExtract(output,"French30")
# Out:
# Song Number:
# 1
# Start Command
# Finished Command
# Song Number:
# 2
# Start Command
# Finished Command
# Song Number:
# 3
# Start Command
# Finished Command
# Song Number:
# 4
# Start Command
# Finished Command
# Song Number:
# 5
# Start Command
# Finished Command
# Song Number:
# 6
# Start Command
# Finished Command
# Song Number:
# 7
# Start Command
# Finished Command
# Song Number:
# 8
# Start Command
# Finished Command
# Song Number:
# 9
# Start Command
# Finished Command
# Song Number:
# 10
# Start Command
# Finished Command
# Song Number:
# 11
# Start Command
# Finished Command
# Song Number:
# 12
# Start Command
# Finished Command
# Song Number:
# 13
# Start Command
# Finished Command
# Song Number:
# 14
# Start Command
# Finished Command
# Song Number:
# 15
# Start Command
# Finished Command
# Song Number:
# 16
# Start Command
# Finished Command
# Song Number:
# 17
# Start Command
# Finished Command
# Song Number:
# 18
# Start Command
# Finished Command
# Song Number:
# 19
# Start Command
# Finished Command
# Song Number:
# 20
# Start Command
# Finished Command
# Song Number:
# 21
# Start Command
# Finished Command
# Song Number:
# 22
# Start Command
# Finished Command
# Song Number:
# 23
# Start Command
# Finished Command
# Song Number:
# 24
# Start Command
# Finished Command
# Song Number:
# 25
# Start Command
# Finished Command
# Song Number:
# 26
# Start Command
# Finished Command
# Song Number:
# 27
# Start Command
# Finished Command
# Song Number:
# 28
# Start Command
# Finished Command
# Song Number:
# 29
# Start Command
# Finished Command
# Song Number:
# 30
# Start Command
# Finished Command
# Song Number:
# 31
# Start Command
# Finished Command
# Song Number:
# 32
# Start Command
# Finished Command
# Song Number:
# 33
# Start Command
# Finished Command
# Song Number:
# 34
# Start Command
# Finished Command
# Song Number:
# 35
# Start Command
# Finished Command
# Song Number:
# 36
# Start Command
# Finished Command
# Song Number:
# 37
# Start Command
# Finished Command
# Song Number:
# 38
# Start Command
# Finished Command
# Song Number:
# 39
# Start Command
# Finished Command
# Song Number:
# 40
# Start Command
# Finished Command
# Song Number:
# 41
# Start Command
# Finished Command
# Song Number:
# 42
# Start Command
# Finished Command
# Song Number:
# 43
# Start Command
# Finished Command
# Song Number:
# 44
# Start Command
# Finished Command
# Song Number:
# 45
# Start Command
# Finished Command
# Song Number:
# 46
# Start Command
# Finished Command
# Song Number:
# 47
# Start Command
# Finished Command
# Song Number:
# 48
# Start Command
# Finished Command
# Song Number:
# 49
# Start Command
# Finished Command
# Song Number:
# 50
# Start Command
# Finished Command
# Song Number:
# 51
# Start Command
# Finished Command
# Song Number:
# 52
# Start Command
# Finished Command
# Song Number:
# 53
# Start Command
# Finished Command
# Song Number:
# 54
# Start Command
# Finished Command
# Song Number:
# 55
# Start Command
# Finished Command
# Song Number:
# 56
# Start Command
# Finished Command
# Song Number:
# 57
# Start Command
# Finished Command
# Song Number:
# 58
# Start Command
# Finished Command
# Song Number:
# 59
# Start Command
# Finished Command
# Song Number:
# 60
# Start Command
# Finished Command
# Song Number:
# 61
# Start Command
# Finished Command
# Song Number:
# 62
# Start Command
# Finished Command
# Song Number:
# 63
# Start Command
# Finished Command
# Song Number:
# 64
# Start Command
# Finished Command
# Song Number:
# 65
# Start Command
# Finished Command
# Song Number:
# 66
# Start Command
# Finished Command
# Song Number:
# 67
# Start Command
# Finished Command
# Song Number:
# 68
# Start Command
# Finished Command
# Song Number:
# 69
# Start Command
# Finished Command
# Song Number:
# 70
# Start Command
# Finished Command
# Song Number:
# 71
# Start Command
# Finished Command
# Song Number:
# 72
# Start Command
# Finished Command
# Song Number:
# 73
# Start Command
# Finished Command
# Song Number:
# 74
# Start Command
# Finished Command
# Song Number:
# 75
# Start Command
# Finished Command
# Song Number:
# 76
# Start Command
# Finished Command
# Song Number:
# 77
# Start Command
# Finished Command
# Song Number:
# 78
# Start Command
# Finished Command
# Song Number:
# 79
# Start Command
# Finished Command
# Song Number:
# 80
# Start Command
# Finished Command
# Song Number:
# 81
# Start Command
# Finished Command
# Song Number:
# 82
# Start Command
# Finished Command
# Song Number:
# 83
# Start Command
# Finished Command
# Song Number:
# 84
# Start Command
# Finished Command
# Song Number:
# 85
# Start Command
# Finished Command
# Song Number:
# 86
# Start Command
# Finished Command
# Song Number:
# 87
# Start Command
# Finished Command
# Song Number:
# 88
# Start Command
# Finished Command
# Song Number:
# 89
# Start Command
# Finished Command
# Song Number:
# 90
# Start Command
# Finished Command
# Song Number:
# 91
# Start Command
# Finished Command

# %%
locationGerman = "/media/russell/775C-44EC/German"
dirGerman =   os.listdir(locationGerman)
count = 0
for j in range(0,len(dirGerman)):
            germanSong = dirGerman[j]
            name, ext = os.path.splitext(germanSong)
            if(ext=='.wav'):
                count+=1
                print("Song Number: ")
                print(count)
                output = readInWav(locationGerman+"/",germanSong)
                betterVocalExtract(output,"German")
# Out:
# Song Number:
# 1
# Start Command
# Finished Command
# Song Number:
# 2
# Start Command
# Finished Command
# Song Number:
# 3
# Start Command
# Finished Command
# Song Number:
# 4
# Start Command
# Finished Command
# Song Number:
# 5
# Start Command
# Finished Command
# Song Number:
# 6
# Start Command
# Finished Command
# Song Number:
# 7
# Start Command
# Finished Command
# Song Number:
# 8
# Start Command
# Finished Command
# Song Number:
# 9
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     126     try:
# --> 127         with sf.SoundFile(path) as sf_desc:
#     128             sr_native = sf_desc.samplerate
#
# ~/anaconda3/lib/python3.7/site-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     626                                          format, subtype, endian)
# --> 627         self._file = self._open(file, mode_int, closefd)
#     628         if set(mode).issuperset('r+') and self.seekable():
#
# ~/anaconda3/lib/python3.7/site-packages/soundfile.py in _open(self, file, mode_int, closefd)
#    1181         _error_check(_snd.sf_error(file_ptr),
# -> 1182                      "Error opening {0!r}: ".format(self.name))
#    1183         if mode_int == _snd.SFM_WRITE:
#
# ~/anaconda3/lib/python3.7/site-packages/soundfile.py in _error_check(err, prefix)
#    1354         err_str = _snd.sf_error_number(err)
# -> 1355         raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#    1356
#
# RuntimeError: Error opening '/media/russell/775C-44EC/German/YoutubeGerman.py': File contains data in an unknown format.
#
# During handling of the above exception, another exception occurred:
#
# NoBackendError                            Traceback (most recent call last)
# <ipython-input-7-138f76a6e574> in <module>()
#       8                 print("Song Number: ")
#       9                 print(count)
# ---> 10                 output = readInWav(locationGerman+"/",germanSong)
#      11                 betterVocalExtract(output,"German")
#
# <ipython-input-5-cce7b311cb29> in readInWav(local, wavFile)
#       1 def readInWav(local, wavFile):
#       2         wavFile = local+wavFile
# ----> 3         outFile=libroExtract(wavFile)
#       4         return outFile
#
# <ipython-input-4-16362b8766ea> in libroExtract(inputSong)
#       8     outSong = outSong.replace('"','')
#       9     outSong = outSong.replace(" ",'')
# ---> 10     y, sr = librosa.load(inputSong,offset=35.0,duration=30)
#      11     librosa.output.write_wav(outSong,y,sr)
#      12     return outSong
#
# ~/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     140     except RuntimeError as exc:
#     141         # If soundfile failed, fall back to the audioread loader
# --> 142         y, sr_native = __audioread_load(path, offset, duration, dtype)
#     143
#     144     # Final cleanup for dtype and contiguity
#
# ~/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py in __audioread_load(path, offset, duration, dtype)
#     162
#     163     y = []
# --> 164     with audioread.audio_open(path) as input_file:
#     165         sr_native = input_file.samplerate
#     166         n_channels = input_file.channels
#
# ~/anaconda3/lib/python3.7/site-packages/audioread/__init__.py in audio_open(path, backends)
#     114
#     115     # All backends failed!
# --> 116     raise NoBackendError()
#
# NoBackendError:

# %%
locationJapanese = "/media/russell/775C-44EC/Japanese"
dirJapanese = os.listdir(locationJapanese)
count=0
for k in range(0,len(dirJapanese)):
            japaneseSong = dirJapanese[k]
            name, ext = os.path.splitext(japaneseSong)
            if(ext=='.wav'):
                count+=1
                print("Song Number:")
                print(count)
                output = readInWav(locationJapanese+"/",japaneseSong)
                betterVocalExtract(output,"Japanese")

# %%
locationJapanese = "/media/russell/775C-44EC/testEnglish"
dirJapanese = os.listdir(locationJapanese)
count=0
for k in range(0,len(dirJapanese)):
            japaneseSong = dirJapanese[k]
            name, ext = os.path.splitext(japaneseSong)
            if(ext=='.wav'):
                count+=1
                print("Song Number:")
                print(count)
                output = readInWav(locationJapanese+"/",japaneseSong)
                betterVocalExtract(output,"testEnglish")
# Out:
# Song Number:
# 1
# Start Command
# Finished Command
# Song Number:
# 2
# Start Command
# Finished Command
# Song Number:
# 3
# Start Command
# Finished Command
# Song Number:
# 4
# Start Command
# Finished Command
# Song Number:
# 5
# Start Command
# Finished Command
# Song Number:
# 6
# Start Command
# Finished Command
# Song Number:
# 7
# Start Command
# Finished Command
# Song Number:
# 8
# Start Command
# Finished Command
# Song Number:
# 9
# Start Command
# Finished Command
# Song Number:
# 10
# Start Command
# Finished Command
# Song Number:
# 11
# Start Command
# Finished Command
# Song Number:
# 12
# Start Command
# Finished Command
# Song Number:
# 13
# Start Command
# Finished Command
# Song Number:
# 14
# Start Command
# Finished Command
# Song Number:
# 15
# Start Command
# Finished Command
# Song Number:
# 16
# Start Command
# Finished Command
# Song Number:
# 17
# Start Command
# Finished Command
# Song Number:
# 18
# Start Command
# Finished Command
# Song Number:
# 19
# Start Command
# Finished Command
# Song Number:
# 20
# Start Command
# Finished Command

# %%
locationJapanese = "/media/russell/775C-44EC/testFrench"
dirJapanese = os.listdir(locationJapanese)
count=0
for k in range(0,len(dirJapanese)):
            japaneseSong = dirJapanese[k]
            name, ext = os.path.splitext(japaneseSong)
            if(ext=='.wav'):
                count+=1
                print("Song Number:")
                print(count)
                output = readInWav(locationJapanese+"/",japaneseSong)
                betterVocalExtract(output,"testFrench")
# Out:
# Song Number:
# 1
# Start Command
# Finished Command
# Song Number:
# 2
# Start Command
# Finished Command
# Song Number:
# 3
# Start Command
# Finished Command
# Song Number:
# 4
# Start Command
# Finished Command
# Song Number:
# 5
# Start Command
# Finished Command
# Song Number:
# 6
# Start Command
# Finished Command
# Song Number:
# 7
# Start Command
# Finished Command
# Song Number:
# 8
# Start Command
# Finished Command
# Song Number:
# 9
# Start Command
# Finished Command
# Song Number:
# 10
# Start Command
# Finished Command

# %%
locationJapanese = "/media/russell/775C-44EC/testGerman"
dirJapanese = os.listdir(locationJapanese)
count=0
for k in range(0,len(dirJapanese)):
            japaneseSong = dirJapanese[k]
            name, ext = os.path.splitext(japaneseSong)
            if(ext=='.wav'):
                count+=1
                print("Song Number:")
                print(count)
                output = readInWav(locationJapanese+"/",japaneseSong)
                betterVocalExtract(output,"testGerman")
# Out:
# Song Number:
# 1
# Start Command
# Finished Command
# Song Number:
# 2
# Start Command
# Finished Command
# Song Number:
# 3
# Start Command
# Finished Command
# Song Number:
# 4
# Start Command
# Finished Command
# Song Number:
# 5
# Start Command
# Finished Command
# Song Number:
# 6
# Start Command
# Finished Command
# Song Number:
# 7
# Start Command
# Finished Command
# Song Number:
# 8
# Start Command
# Finished Command
# Song Number:
# 9
# Start Command
# Finished Command
# Song Number:
# 10
# Start Command
# Finished Command

# %%
locationJapanese = "/media/russell/775C-44EC/testJapanese"
dirJapanese = os.listdir(locationJapanese)
count=0
for k in range(0,len(dirJapanese)):
            japaneseSong = dirJapanese[k]
            name, ext = os.path.splitext(japaneseSong)
            if(ext=='.wav'):
                count+=1
                print("Song Number:")
                print(count)
                output = readInWav(locationJapanese+"/",japaneseSong)
                betterVocalExtract(output,"testJapanese")
# Out:
# Song Number:
# 1
# Start Command
# Finished Command
# Song Number:
# 2
# Start Command
# Finished Command
# Song Number:
# 3
# Start Command
# Finished Command
# Song Number:
# 4
# Start Command
# Finished Command
# Song Number:
# 5
# Start Command
# Finished Command
# Song Number:
# 6
# Start Command
# Finished Command
# Song Number:
# 7
# Start Command
# Finished Command
# Song Number:
# 8
# Start Command
# Finished Command
# Song Number:
# 9
# Start Command
# Finished Command
# Song Number:
# 10
# Start Command
# Finished Command
# Song Number:
# 11
# Start Command
# Finished Command
# Song Number:
# 12
# Start Command
# Finished Command
# Song Number:
# 13
# Start Command
# Finished Command
# Song Number:
# 14
# Start Command
# Finished Command
# Song Number:
# 15
# Start Command
# Finished Command
# Song Number:
# 16
# Start Command
# Finished Command
# Song Number:
# 17
# Start Command
# Finished Command
# Song Number:
# 18
# Start Command
# Finished Command
# Song Number:
# 19
# Start Command
# Finished Command
# Song Number:
# 20
# Start Command
# Finished Command
